# %% [markdown]
# # GTSRB - German Traffic Sign Recognition Benchmark

# %% [markdown]
# <img src='traffic.jpg'>

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
np.random.seed(42)

from matplotlib import style
style.use('fivethirtyeight')

# %%
train_df = pd.read_csv('Train.csv')

# %%
train_df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path
# 0  Train/20/00020_00000_00000.png
# 1  Train/20/00020_00000_00001.png
# 2  Train/20/00020_00000_00002.png
# 3  Train/20/00020_00000_00003.png
# 4  Train/20/00020_00000_00004.png

# %%
train_df = train_df.drop(['Width', 'Height', 'Roi.X1', 'Roi.Y1', 'Roi.X2', 'Roi.Y2'], axis = 1)
train_df.head()
# Out:
#    ClassId                            Path
# 0       20  Train/20/00020_00000_00000.png
# 1       20  Train/20/00020_00000_00001.png
# 2       20  Train/20/00020_00000_00002.png
# 3       20  Train/20/00020_00000_00003.png
# 4       20  Train/20/00020_00000_00004.png

# %%
df_label=pd.read_csv('labels.csv')

# %%
df_label.head()
# Out:
#    ClassId                  Name
# 0        0   Speed limit (5km/h)
# 1        1  Speed limit (15km/h)
# 2        2  Speed limit (30km/h)
# 3        3  Speed limit (40km/h)
# 4        4  Speed limit (50km/h)

# %%
train_path= 'Train'
NUM_CATEGORIES = len(os.listdir(train_path))
NUM_CATEGORIES
# Out:
# 43

# %%
dir_path = 'C:\\Users\\PC11\Desktop\\AI\\projects\\Capstone_Project\\'
os.listdir(dir_path)
# Out:
# ['.ipynb_checkpoints',
#  'Capstone_Project.ipynb',
#  'labels.csv',
#  'links.txt',
#  'Meta',
#  'Meta.csv',
#  'Test',
#  'Test.csv',
#  'traffic.jpg',
#  'traffic_files',
#  'Train',
#  'Train.csv']

# %%
from matplotlib.image import imread
dim1 = []
dim2 = []

for i in range(0,43):
    labels = train_path + '/{0}'.format(i)
    image_path = os.listdir(labels)
    for x in image_path:
        img = imread(labels + '/' + x)
        dim1.append(img.shape[0])
        dim2.append(img.shape[1])

# %%
np.mean(dim1),np.mean(dim2)
# Out:
# (50.328929582493814, 50.83587951745773)

# %%
image_shape = (30,30)

# %%
data_dic = {}
for folder in os.listdir(train_path):
    data_dic[folder] = len(os.listdir(train_path + '/' + folder))

data_df= pd.Series(data_dic)
plt.figure(figsize = (15, 6))
data_df.sort_values().plot(kind = 'bar')
plt.xlabel('Classes')
plt.ylabel('Number of images')
# Out:
# Text(0, 0.5, 'Number of images')

# %% [raw]
# Visualizing 25 random images from test data

# %%
import random
from matplotlib.image import imread

test = pd.read_csv(dir_path + '/Test.csv')
imgs = test["Path"].values

plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    random_img_path = dir_path + '/' + random.choice(imgs)
    rand_img = imread(random_img_path)
    plt.imshow(rand_img)
    ##plt.grid(b=None)
    plt.grid(color='r', linestyle='-', linewidth=2)
    plt.xlabel(rand_img.shape[1], fontsize = 20)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 20)#height of image

# %% [raw]
# Collecting the Training Data

# %%
IMG_HEIGHT = 30
IMG_WIDTH = 30
channels = 3
image_data = []
image_labels = []

for i in range(NUM_CATEGORIES):
    path = dir_path + '/Train/' + str(i)
    images = os.listdir(path)

    for img in images:
        try:
            image = cv2.imread(path + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %%
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.3, random_state=42, shuffle=True)

X_train = X_train/255 
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (27446, 30, 30, 3)
# X_valid.shape (11763, 30, 30, 3)
# y_train.shape (27446,)
# y_valid.shape (11763,)

# %% [raw]
# One hot encoding the labels

# %%
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 43)
# (11763, 43)

# %% [raw]
# Making the model

# %%
model = keras.models.Sequential([    
    keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu', input_shape=(IMG_HEIGHT,IMG_WIDTH,channels)),
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(rate=0.5),
    
    keras.layers.Dense(43, activation='softmax')
])

# %%
##pip install visualkeras

# %%
import visualkeras
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=701x150>

# %%
lr = 0.001
epochs = 30
opt = tf.keras.optimizers.legacy.Adam(lr=lr, decay=lr / (epochs * 0.5))
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        4640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 13, 13, 32)       128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 9, 9, 128)         73856
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 43)                22059
#
# =================================================================
# Total params: 1,171,275
# Trainable params: 1,169,931
# Non-trainable params: 1,344
# _________________________________________________________________

# %% [raw]
# Augmenting the data and training the model

# %%
aug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.15,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode="nearest")

history = model.fit(aug.flow(X_train, y_train, batch_size=32), epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 858/858 [==============================] - 40s 45ms/step - loss: 0.9841 - accuracy: 0.7319 - val_loss: 0.0797 - val_accuracy: 0.9784
# Epoch 2/30
# 858/858 [==============================] - 43s 50ms/step - loss: 0.1793 - accuracy: 0.9437 - val_loss: 0.0361 - val_accuracy: 0.9887
# Epoch 3/30
# 858/858 [==============================] - 41s 47ms/step - loss: 0.1117 - accuracy: 0.9659 - val_loss: 0.0252 - val_accuracy: 0.9916
# Epoch 4/30
# 858/858 [==============================] - 42s 48ms/step - loss: 0.0927 - accuracy: 0.9715 - val_loss: 0.0193 - val_accuracy: 0.9941
# Epoch 5/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0865 - accuracy: 0.9749 - val_loss: 0.0254 - val_accuracy: 0.9924
# Epoch 6/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0619 - accuracy: 0.9805 - val_loss: 0.0151 - val_accuracy: 0.9957
# Epoch 7/30
# 858/858 [==============================] - 43s 50ms/step - loss: 0.0625 - accuracy: 0.9799 - val_loss: 0.0197 - val_accuracy: 0.9942
# Epoch 8/30
# 858/858 [==============================] - 43s 51ms/step - loss: 0.0613 - accuracy: 0.9812 - val_loss: 0.0187 - val_accuracy: 0.9953
# Epoch 9/30
# 858/858 [==============================] - 41s 48ms/step - loss: 0.0581 - accuracy: 0.9823 - val_loss: 0.0305 - val_accuracy: 0.9901
# Epoch 10/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0504 - accuracy: 0.9850 - val_loss: 0.0078 - val_accuracy: 0.9974
# Epoch 11/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0522 - accuracy: 0.9844 - val_loss: 0.0069 - val_accuracy: 0.9980
# Epoch 12/30
# 858/858 [==============================] - 42s 48ms/step - loss: 0.0444 - accuracy: 0.9868 - val_loss: 0.0062 - val_accuracy: 0.9984
# Epoch 13/30
# 858/858 [==============================] - 43s 50ms/step - loss: 0.0375 - accuracy: 0.9883 - val_loss: 0.0170 - val_accuracy: 0.9952
# Epoch 14/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.0049 - val_accuracy: 0.9985
# Epoch 15/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0328 - accuracy: 0.9893 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 16/30
# 858/858 [==============================] - 196s 228ms/step - loss: 0.0347 - accuracy: 0.9894 - val_loss: 0.0104 - val_accuracy: 0.9964
# Epoch 17/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.0060 - val_accuracy: 0.9986
# Epoch 18/30
# 858/858 [==============================] - 41s 48ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.0102 - val_accuracy: 0.9972
# Epoch 19/30
# 858/858 [==============================] - 43s 50ms/step - loss: 0.0345 - accuracy: 0.9894 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 20/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0320 - accuracy: 0.9909 - val_loss: 0.0238 - val_accuracy: 0.9920
# Epoch 21/30
# 858/858 [==============================] - 600s 700ms/step - loss: 0.0300 - accuracy: 0.9914 - val_loss: 0.0068 - val_accuracy: 0.9977
# Epoch 22/30
# 858/858 [==============================] - 44s 51ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.0038 - val_accuracy: 0.9989
# Epoch 23/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0275 - accuracy: 0.9919 - val_loss: 0.0075 - val_accuracy: 0.9978
# Epoch 24/30
# 858/858 [==============================] - 43s 51ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.0048 - val_accuracy: 0.9986
# Epoch 25/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0246 - accuracy: 0.9931 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 26/30
# 858/858 [==============================] - 43s 50ms/step - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.0061 - val_accuracy: 0.9984
# Epoch 27/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.0119 - val_accuracy: 0.9965
# Epoch 28/30
# 858/858 [==============================] - 44s 52ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 29/30
# 858/858 [==============================] - 42s 49ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0111 - val_accuracy: 0.9973
# Epoch 30/30
# 858/858 [==============================] - 44s 51ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0053 - val_accuracy: 0.9984

# %% [raw]
# Evaluating the model

# %%
import seaborn as sns
fig, ax=plt.subplots(2,1,figsize=(12,10))
fig.suptitle('Train evaluation')

sns.lineplot(ax= ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['accuracy'])
sns.lineplot(ax= ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['val_accuracy'])

ax[0].legend(['Train','Validation'])
ax[0].set_title('Accuracy')

sns.lineplot(ax= ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['loss'])
sns.lineplot(ax= ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['val_loss'])

ax[1].legend(['Train','Validation'])
ax[1].set_title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %% [raw]
# Loading the test data and running the predictions

# %%
test = pd.read_csv(dir_path + '/Test.csv')

labels = test["ClassId"].values
imgs = test["Path"].values

data =[]

for img in imgs:
    try:
        image = cv2.imread(dir_path + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        data.append(np.array(resize_image))
    except:
        print("Error in " + img)
X_test = np.array(data)
# X_test = X_test/255

pred = model.predict(X_test)

#Accuracy with the test data
# print('Test Data accuracy: ',accuracy_score(labels, pred)*100)
# Out:
# 395/395 [==============================] - 5s 11ms/step
